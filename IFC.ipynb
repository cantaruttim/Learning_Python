# %% [markdown]
# <a href="https://colab.research.google.com/github/cantaruttim/Learning_Python/blob/main/IFC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# Private sector development requires more than just finance. Experience shows the powerful role advisory services can play in unlocking investment and helping businesses expand and create jobs.
# To help the private sector in emerging markets, IFC provides advice, problem solving, and training to companies, industries, and governments. Our experience shows that companies need more than financial investment to thrive—they need a regulatory environment that enables entrepreneurship, and advice on business best practices. Our work includes advising national and local governments on how to improve their investment climate and strengthen basic infrastructure. Governments account for around half of our advisory projects. We also help investment clients improve corporate governance and become more sustainable.
#
# [Documentação](https://dev.socrata.com/foundry/finances.worldbank.org/b74b-t2z3)
#
# [worldbank](https://datacatalog.worldbank.org/home)

# %%
dataset = pd.read_csv('https://finances.worldbank.org/resource/b74b-t2z3.csv')
dataset
# Out:
#              disclosure_date  project_number  \
# 0    2023-04-13T00:00:00.000          607356
# 1    2023-04-13T00:00:00.000          607265
# 2    2023-04-13T00:00:00.000          606572
# 3    2023-04-03T00:00:00.000          606828
# 4    2023-04-03T00:00:00.000          607263
# ..                       ...             ...
# 995  2014-04-02T00:00:00.000          597607
# 996  2014-03-28T00:00:00.000          599522
# 997  2014-03-28T00:00:00.000          600103
# 998  2014-03-27T00:00:00.000          599624
# 999  2014-03-20T00:00:00.000          600218
#
#                                           project_name  \
# 0    Ethiopia Financial Institutions Risk Managemen...
# 1    CCF II  Scaling up and sustaining WRF in Ethiopia
# 2      Solomon Islands Tourism Investment Facilitation
# 3                        GuineTel Bissau Privatization
# 4                 VPBank Supply Chain Finance Advisory
# ..                                                 ...
# 995             Indonesia Secured Transactions Project
# 996                               Bhutan National Bank
# 997            Accelerating Sustainable Business Entry
# 998            South Asia Corporate Governance Program
# 999                                     Bank al Etihad
#
#                                            project_url               country  \
# 0    https://disclosures.ifc.org/project-detail/AS/...              Ethiopia
# 1    https://disclosures.ifc.org/project-detail/AS/...              Ethiopia
# 2    https://disclosures.ifc.org/project-detail/AS/...       Solomon Islands
# 3    https://disclosures.ifc.org/project-detail/AS/...         Guinea-Bissau
# 4    https://disclosures.ifc.org/project-detail/AS/...               Vietnam
# ..                                                 ...                   ...
# 995  https://disclosures.ifc.org/project-detail/AS/...             Indonesia
# 996  https://disclosures.ifc.org/project-detail/AS/...                Bhutan
# 997  https://disclosures.ifc.org/project-detail/AS/...  Latin America Region
# 998  https://disclosures.ifc.org/project-detail/AS/...                 India
# 999  https://disclosures.ifc.org/project-detail/AS/...                Jordan
#
#     ifc_country_code                                      region  \
# 0                ETH                                      Africa
# 1                ETH                                      Africa
# 2                SLI                   East Asia and the Pacific
# 3                GUB                                      Africa
# 4                VNM                   East Asia and the Pacific
# ..               ...                                         ...
# 995              INS                   East Asia and the Pacific
# 996              BHU                                  South Asia
# 997              LAC  Latin America and the Caribbean and Europe
# 998              IND                                  South Asia
# 999              JOR                                 Middle East
#
#                      business_line  estimated_total_budget  department  \
# 0     Financial Institutions Group                950000.0         NaN
# 1     Financial Institutions Group                800000.0         NaN
# 2                            Other               1900000.0         NaN
# 3             Transaction Advisory               1580000.0         NaN
# 4     Financial Institutions Group                 75000.0         NaN
# ..                             ...                     ...         ...
# 995              Access To Finance               1553406.0         NaN
# 996              Access To Finance                165000.0         NaN
# 997             Investment Climate               1202450.0         NaN
# 998  Sustainable Business Advisory                530000.0         NaN
# 999              Access To Finance                578600.0         NaN
#
#         status        ifc_approval_date     projected_start_date country_code  \
# 0       Active  2022-09-24T00:00:00.000  2022-08-15T00:00:00.000           ET
# 1       Active  2022-09-02T00:00:00.000  2022-07-01T00:00:00.000           ET
# 2       Active  2022-07-21T00:00:00.000  2022-07-01T00:00:00.000           SB
# 3       Active  2022-07-22T00:00:00.000  2022-06-30T00:00:00.000          NaN
# 4       Active  2022-08-05T00:00:00.000  2022-07-13T00:00:00.000           VN
# ..         ...                      ...                      ...          ...
# 995  Completed  2014-02-20T00:00:00.000                      NaN           ID
# 996  Completed  2014-01-31T00:00:00.000                      NaN           BT
# 997  Completed  2013-12-27T00:00:00.000                      NaN           33
# 998  Completed  2014-01-28T00:00:00.000                      NaN           IN
# 999  Completed  2014-01-06T00:00:00.000                      NaN           JO
#
#                   as_of_date
# 0    2023-04-20T02:05:00.000
# 1    2023-04-20T02:05:00.000
# 2    2023-04-20T02:05:00.000
# 3    2023-04-20T02:05:00.000
# 4    2023-04-20T02:05:00.000
# ..                       ...
# 995  2023-04-20T02:05:00.000
# 996  2023-04-20T02:05:00.000
# 997  2023-04-20T02:05:00.000
# 998  2023-04-20T02:05:00.000
# 999  2023-04-20T02:05:00.000
#
# [1000 rows x 15 columns]

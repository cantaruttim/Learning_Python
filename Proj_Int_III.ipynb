# %% [markdown]
# <a href="https://colab.research.google.com/github/cantaruttim/Learning_Python/blob/main/Proj_Int_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Base (Raw)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/countries of the world.csv")

# %%
dataset.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# 2         -0,39                                 31              6000.0
# 3        -20,71                               9,27              8000.0
# 4           6,6                               4,05             19000.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
# 2         70,0              78,1       3,22      0,25     96,53       1
# 3         97,0             259,5         10        15        75       2
# 4        100,0             497,2       2,22         0     97,78       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# 1     15,11      5,22       0,232    0,188   0,579
# 2     17,14      4,61       0,101      0,6   0,298
# 3     22,46      3,27         NaN      NaN     NaN
# 4      8,71      6,25         NaN      NaN     NaN

# %%
dataset.drop(columns=['Arable (%)', 'Other (%)', 'Crops (%)', 'Climate', 'Agriculture', 'Industry', 'Service'], inplace = True)

# %%
dataset.columns
# 1 mi² = 2,59 km
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Birthrate',
#        'Deathrate'],
#       dtype='object')

# %%
dataset.columns = ['País', 'Região', 'População', 'Área (Km)', 'Densidade Populacional', 'Área Costeira (costa/Área)', 
 'Taxa de Migração', 'Taxa de Mortalidade Infantil (por 1000 nascimentos)', 'Renda Per capita ($)', 'Taxa de Alfabetização (%)',
 'Telefones (por 1000)', 'Taxa de Natalidade', 'Taxa de Óbito']

# %%
dataset
# Out:
#                 País                               Região  População  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)            31056997
# 1           Albania   EASTERN EUROPE                         3581655
# 2           Algeria   NORTHERN AFRICA                       32930091
# 3    American Samoa   OCEANIA                                  57794
# 4           Andorra   WESTERN EUROPE                           71201
# ..               ...                                  ...        ...
# 222       West Bank   NEAR EAST                              2460492
# 223  Western Sahara   NORTHERN AFRICA                         273008
# 224           Yemen   NEAR EAST                             21456188
# 225          Zambia   SUB-SAHARAN AFRICA                    11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                    12236805
#
#      Área (Km) Densidade Populacional Área Costeira (costa/Área)  \
# 0       647500                   48,0                       0,00
# 1        28748                  124,6                       1,26
# 2      2381740                   13,8                       0,04
# 3          199                  290,4                      58,29
# 4          468                  152,1                       0,00
# ..         ...                    ...                        ...
# 222       5860                  419,9                       0,00
# 223     266000                    1,0                       0,42
# 224     527970                   40,6                       0,36
# 225     752614                   15,3                       0,00
# 226     390580                   31,3                       0,00
#
#     Taxa de Migração Taxa de Mortalidade Infantil (por 1000 nascimentos)  \
# 0              23,06                                             163,07
# 1              -4,93                                              21,52
# 2              -0,39                                                 31
# 3             -20,71                                               9,27
# 4                6,6                                               4,05
# ..               ...                                                ...
# 222             2,98                                              19,62
# 223              NaN                                                NaN
# 224                0                                               61,5
# 225                0                                              88,29
# 226                0                                              67,69
#
#      Renda Per capita ($) Taxa de Alfabetização (%) Telefones (por 1000)  \
# 0                   700.0                      36,0                  3,2
# 1                  4500.0                      86,5                 71,2
# 2                  6000.0                      70,0                 78,1
# 3                  8000.0                      97,0                259,5
# 4                 19000.0                     100,0                497,2
# ..                    ...                       ...                  ...
# 222                 800.0                       NaN                145,2
# 223                   NaN                       NaN                  NaN
# 224                 800.0                      50,2                 37,2
# 225                 800.0                      80,6                  8,2
# 226                1900.0                      90,7                 26,8
#
#     Taxa de Natalidade Taxa de Óbito
# 0                 46,6         20,34
# 1                15,11          5,22
# 2                17,14          4,61
# 3                22,46          3,27
# 4                 8,71          6,25
# ..                 ...           ...
# 222              31,67          3,92
# 223                NaN           NaN
# 224              42,89           8,3
# 225                 41         19,93
# 226              28,01         21,84
#
# [227 rows x 13 columns]

# %%
dataset.head().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   País                                                 5 non-null      object
#  1   Região                                               5 non-null      object
#  2   População                                            5 non-null      int64
#  3   Área (Km)                                            5 non-null      int64
#  4   Densidade Populacional                               5 non-null      object
#  5   Área Costeira (costa/Área)                           5 non-null      object
#  6   Taxa de Migração                                     5 non-null      object
#  7   Taxa de Mortalidade Infantil (por 1000 nascimentos)  5 non-null      object
#  8   Renda Per capita ($)                                 5 non-null      float64
#  9   Taxa de Alfabetização (%)                            5 non-null      object
#  10  Telefones (por 1000)                                 5 non-null      object
#  11  Taxa de Natalidade                                   5 non-null      object
#  12  Taxa de Óbito                                        5 non-null      object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 648.0+ bytes

# %%
dataset.isnull().sum() / len(dataset) * 100
# Out:
# País                                                   0.000000
# Região                                                 0.000000
# População                                              0.000000
# Área (Km)                                              0.000000
# Densidade Populacional                                 0.000000
# Área Costeira (costa/Área)                             0.000000
# Taxa de Migração                                       1.321586
# Taxa de Mortalidade Infantil (por 1000 nascimentos)    1.321586
# Renda Per capita ($)                                   0.440529
# Taxa de Alfabetização (%)                              7.929515
# Telefones (por 1000)                                   1.762115
# Taxa de Natalidade                                     1.321586
# Taxa de Óbito                                          1.762115
# dtype: float64

# %%
dataset['Densidade Populacional'] = dataset['Densidade Populacional'].str.replace(',', '.')
dataset['Área Costeira (costa/Área)'] = dataset['Área Costeira (costa/Área)'].str.replace(',', '.')
dataset['Taxa de Migração'] = dataset['Taxa de Migração'].str.replace(',', '.')
dataset['Taxa de Mortalidade Infantil (por 1000 nascimentos)'] = dataset['Taxa de Mortalidade Infantil (por 1000 nascimentos)'].str.replace(',', '.')
dataset['Taxa de Alfabetização (%)'] = dataset['Taxa de Alfabetização (%)'].str.replace(',', '.')
dataset['Telefones (por 1000)'] = dataset['Telefones (por 1000)'].str.replace(',', '.')
dataset['Taxa de Natalidade'] = dataset['Taxa de Natalidade'].str.replace(',', '.')
dataset['Taxa de Óbito'] = dataset['Taxa de Óbito'].str.replace(',', '.')

# %%
dataset['Densidade Populacional'] = pd.Series(dataset['Densidade Populacional'], dtype = 'float')
dataset['Área Costeira (costa/Área)'] = pd.Series(dataset['Área Costeira (costa/Área)'], dtype = 'float')
dataset['Taxa de Migração'] = pd.Series(dataset['Taxa de Migração'], dtype='float')
dataset['Taxa de Mortalidade Infantil (por 1000 nascimentos)'] = pd.Series(dataset['Taxa de Mortalidade Infantil (por 1000 nascimentos)'], dtype='float')
dataset['Taxa de Alfabetização (%)'] = pd.Series(dataset['Taxa de Alfabetização (%)'], dtype='float')
dataset['Telefones (por 1000)'] = pd.Series(dataset['Telefones (por 1000)'], dtype = 'float')
dataset['Taxa de Natalidade'] = pd.Series(dataset['Taxa de Natalidade'], dtype='float')
dataset['Taxa de Óbito'] = pd.Series(dataset['Taxa de Óbito'], dtype='float')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 13 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   País                                                 227 non-null    object
#  1   Região                                               227 non-null    object
#  2   População                                            227 non-null    int64
#  3   Área (Km)                                            227 non-null    int64
#  4   Densidade Populacional                               227 non-null    float64
#  5   Área Costeira (costa/Área)                           227 non-null    float64
#  6   Taxa de Migração                                     224 non-null    float64
#  7   Taxa de Mortalidade Infantil (por 1000 nascimentos)  224 non-null    float64
#  8   Renda Per capita ($)                                 226 non-null    float64
#  9   Taxa de Alfabetização (%)                            209 non-null    float64
#  10  Telefones (por 1000)                                 223 non-null    float64
#  11  Taxa de Natalidade                                   224 non-null    float64
#  12  Taxa de Óbito                                        223 non-null    float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 23.2+ KB

# %%
plt.figure(figsize=(10,8))
sns.histplot(dataset['População'], bins=15, kde=True);
plt.show()

# %%
sns.pairplot(dataset);

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=dataset['População'], y=dataset['Renda Per capita ($)'], s=5, color=".15")
sns.histplot(x=dataset['População'], y=dataset['Renda Per capita ($)'], bins=50, pthresh=.1, cmap="mako")
# sns.kdeplot(x=dataset['População'], y=dataset['Renda Per capita ($)'], levels=5, color="w", linewidths=1)
# Out:
# <Axes: xlabel='População', ylabel='Renda Per capita ($)'>

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(x="Renda Per capita ($)", data=dataset.groupby(['País']).mean(),
            whis=[0, 100], width=.6, palette="vlag"); 

# Add in points to show each observation
sns.stripplot(x="Renda Per capita ($)", data=dataset.groupby(['País']).mean(),
              size=4, color="0", linewidth=0);
# Out:
# <ipython-input-16-d4d643d72d3a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.boxplot(x="Renda Per capita ($)", data=dataset.groupby(['País']).mean(),
# <ipython-input-16-d4d643d72d3a>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.stripplot(x="Renda Per capita ($)", data=dataset.groupby(['País']).mean(),

# %%
sns.boxplot(x="Taxa de Natalidade", data=dataset.groupby(['País']).mean(),
            whis=[0, 100], width=.6, palette="vlag"); 

# Add in points to show each observation
sns.stripplot(x="Taxa de Natalidade", data=dataset.groupby(['País']).mean(),
              size=4, color="0", linewidth=0);
# Out:
# <ipython-input-17-90b5e7cbf8ca>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.boxplot(x="Taxa de Natalidade", data=dataset.groupby(['País']).mean(),
# <ipython-input-17-90b5e7cbf8ca>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.stripplot(x="Taxa de Natalidade", data=dataset.groupby(['País']).mean(),

# %%
sns.boxplot(x="Taxa de Óbito", data=dataset.groupby(['País']).mean(),
            whis=[0, 100], width=.6, palette="vlag"); 

# Add in points to show each observation
sns.stripplot(x="Taxa de Óbito", data=dataset.groupby(['País']).mean(),
              size=4, color="0", linewidth=0);
# Out:
# <ipython-input-18-b718b6de3fe9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.boxplot(x="Taxa de Óbito", data=dataset.groupby(['País']).mean(),
# <ipython-input-18-b718b6de3fe9>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.stripplot(x="Taxa de Óbito", data=dataset.groupby(['País']).mean(),

# %%
# telefone vs Renda per Capita

f, ax = plt.subplots(figsize=(10, 6))

sns.despine(f, left=True, bottom=True)

sns.scatterplot(x="Renda Per capita ($)", y="Telefones (por 1000)",
                sizes=(1, 8), linewidth=0,
                data=dataset, ax=ax);

# %%
# salvando o dataset no formato csv (tratado)
dataset.to_csv("countries of the world (tratado).csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a4517b5a2467> in <cell line: 3>()
#       1 # salvando o dataset no formato csv (tratado)
#       2
# ----> 3 dataset.to_csv("countries of the world (tratado).csv", sep=";")
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# # Base (tratada)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
dataset = pd.read_csv("countries of the world (tratado).csv", sep=";")

# %%
dataset.drop(columns="Unnamed: 0", axis = 1, inplace = True)

# %%
dataset.head()
# Out:
#               País                               Região  População  Área (Km)  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)            31056997     647500
# 1         Albania   EASTERN EUROPE                         3581655      28748
# 2         Algeria   NORTHERN AFRICA                       32930091    2381740
# 3  American Samoa   OCEANIA                                  57794        199
# 4         Andorra   WESTERN EUROPE                           71201        468
#
#    Densidade Populacional  Área Costeira (costa/Área)  Taxa de Migração  \
# 0                    48.0                        0.00             23.06
# 1                   124.6                        1.26             -4.93
# 2                    13.8                        0.04             -0.39
# 3                   290.4                       58.29            -20.71
# 4                   152.1                        0.00              6.60
#
#    Taxa de Mortalidade Infantil (por 1000 nascimentos)  Renda Per capita ($)  \
# 0                                             163.07                   700.0
# 1                                              21.52                  4500.0
# 2                                              31.00                  6000.0
# 3                                               9.27                  8000.0
# 4                                               4.05                 19000.0
#
#    Taxa de Alfabetização (%)  Telefones (por 1000)  Taxa de Natalidade  \
# 0                       36.0                   3.2               46.60
# 1                       86.5                  71.2               15.11
# 2                       70.0                  78.1               17.14
# 3                       97.0                 259.5               22.46
# 4                      100.0                 497.2                8.71
#
#    Taxa de Óbito
# 0          20.34
# 1           5.22
# 2           4.61
# 3           3.27
# 4           6.25

# %%
dataset[dataset['Renda Per capita ($)'] >= 20000]
# Out:
#                       País                               Região  População  \
# 10                  Aruba               LATIN AMER. & CARIB          71891
# 11              Australia   OCEANIA                               20264082
# 12                Austria   WESTERN EUROPE                         8192880
# 19                Belgium   WESTERN EUROPE                        10379067
# 22                Bermuda   NORTHERN AMERICA                         65773
# 36                 Canada   NORTHERN AMERICA                      33098932
# 38         Cayman Islands               LATIN AMER. & CARIB          45436
# 54                Denmark   WESTERN EUROPE                         5450661
# 66          Faroe Islands   WESTERN EUROPE                           47246
# 68                Finland   WESTERN EUROPE                         5231372
# 69                 France   WESTERN EUROPE                        60876136
# 76                Germany   WESTERN EUROPE                        82422299
# 79                 Greece   WESTERN EUROPE                        10688058
# 80              Greenland   NORTHERN AMERICA                         56361
# 83                   Guam   OCEANIA                                 171019
# 85               Guernsey   WESTERN EUROPE                           65409
# 91              Hong Kong         ASIA (EX. NEAR EAST)             6940432
# 93                Iceland   WESTERN EUROPE                          299388
# 98                Ireland   WESTERN EUROPE                         4062235
# 99            Isle of Man   WESTERN EUROPE                           75441
# 101                 Italy   WESTERN EUROPE                        58133509
# 103                 Japan         ASIA (EX. NEAR EAST)           127463611
# 104                Jersey   WESTERN EUROPE                           91084
# 119         Liechtenstein   WESTERN EUROPE                           33987
# 121            Luxembourg   WESTERN EUROPE                          474413
# 138                Monaco   WESTERN EUROPE                           32543
# 146           Netherlands   WESTERN EUROPE                        16491461
# 149           New Zealand   OCEANIA                                4076140
# 154                Norway   WESTERN EUROPE                         4610820
# 166                 Qatar   NEAR EAST                               885359
# 177            San Marino   WESTERN EUROPE                           29251
# 184             Singapore         ASIA (EX. NEAR EAST)             4492150
# 190                 Spain   WESTERN EUROPE                        40397842
# 195                Sweden   WESTERN EUROPE                         9016596
# 196           Switzerland   WESTERN EUROPE                         7523934
# 198                Taiwan         ASIA (EX. NEAR EAST)            23036087
# 212  United Arab Emirates   NEAR EAST                              2602713
# 213        United Kingdom   WESTERN EUROPE                        60609153
# 214         United States   NORTHERN AMERICA                     298444215
#
#      Área (Km)  Densidade Populacional  Área Costeira (costa/Área)  \
# 10         193                   372.5                       35.49
# 11     7686850                     2.6                        0.34
# 12       83870                    97.7                        0.00
# 19       30528                   340.0                        0.22
# 22          53                  1241.0                      194.34
# 36     9984670                     3.3                        2.02
# 38         262                   173.4                       61.07
# 54       43094                   126.5                       16.97
# 66        1399                    33.8                       79.84
# 68      338145                    15.5                        0.37
# 69      547030                   111.3                        0.63
# 76      357021                   230.9                        0.67
# 79      131940                    81.0                       10.37
# 80     2166086                     0.0                        2.04
# 83         541                   316.1                       23.20
# 85          78                   838.6                       64.10
# 91        1092                  6355.7                       67.12
# 93      103000                     2.9                        4.83
# 98       70280                    57.8                        2.06
# 99         572                   131.9                       27.97
# 101     301230                   193.0                        2.52
# 103     377835                   337.4                        7.87
# 104        116                   785.2                       60.34
# 119        160                   212.4                        0.00
# 121       2586                   183.5                        0.00
# 138          2                 16271.5                      205.00
# 146      41526                   397.1                        1.09
# 149     268680                    15.2                        5.63
# 154     323802                    14.2                        7.77
# 166      11437                    77.4                        4.92
# 177         61                   479.5                        0.00
# 184        693                  6482.2                       27.85
# 190     504782                    80.0                        0.98
# 195     449964                    20.0                        0.72
# 196      41290                   182.2                        0.00
# 198      35980                   640.3                        4.35
# 212      82880                    31.4                        1.59
# 213     244820                   247.6                        5.08
# 214    9631420                    31.0                        0.21
#
#      Taxa de Migração  Taxa de Mortalidade Infantil (por 1000 nascimentos)  \
# 10               0.00                                               5.89
# 11               3.98                                               4.69
# 12               2.00                                               4.66
# 19               1.23                                               4.68
# 22               2.49                                               8.53
# 36               5.96                                               4.75
# 38              18.75                                               8.19
# 54               2.48                                               4.56
# 66               1.41                                               6.24
# 68               0.95                                               3.57
# 69               0.66                                               4.26
# 76               2.18                                               4.16
# 79               2.35                                               5.53
# 80              -8.37                                              15.82
# 83               0.00                                               6.94
# 85               3.84                                               4.71
# 91               5.24                                               2.97
# 93               2.38                                               3.31
# 98               4.99                                               5.39
# 99               5.36                                               5.93
# 101              2.07                                               5.94
# 103              0.00                                               3.26
# 104              2.76                                               5.24
# 119              4.85                                               4.70
# 121              8.97                                               4.81
# 138              7.75                                               5.43
# 146              2.91                                               5.04
# 149              4.05                                               5.85
# 154              1.74                                               3.70
# 166             16.29                                              18.61
# 177             10.98                                               5.73
# 184             11.53                                               2.29
# 190              0.99                                               4.42
# 195              1.67                                               2.77
# 196              4.05                                               4.39
# 198              0.00                                               6.40
# 212              1.03                                              14.51
# 213              2.19                                               5.16
# 214              3.41                                               6.50
#
#      Renda Per capita ($)  Taxa de Alfabetização (%)  Telefones (por 1000)  \
# 10                28000.0                       97.0                 516.1
# 11                29000.0                      100.0                 565.5
# 12                30000.0                       98.0                 452.2
# 19                29100.0                       98.0                 462.6
# 22                36000.0                       98.0                 851.4
# 36                29800.0                       97.0                 552.2
# 38                35000.0                       98.0                 836.3
# 54                31100.0                      100.0                 614.6
# 66                22000.0                        NaN                 503.8
# 68                27400.0                      100.0                 405.3
# 69                27600.0                       99.0                 586.4
# 76                27600.0                       99.0                 667.9
# 79                20000.0                       97.5                 589.7
# 80                20000.0                        NaN                 448.9
# 83                21000.0                       99.0                 492.0
# 85                20000.0                        NaN                 842.4
# 91                28800.0                       93.5                 546.7
# 93                30900.0                       99.9                 647.7
# 98                29600.0                       98.0                 500.5
# 99                21000.0                        NaN                 676.0
# 101               26700.0                       98.6                 430.9
# 103               28200.0                       99.0                 461.2
# 104               24800.0                        NaN                 811.3
# 119               25000.0                      100.0                 585.5
# 121               55100.0                      100.0                 515.4
# 138               27000.0                       99.0                1035.6
# 146               28600.0                       99.0                 460.8
# 149               21600.0                       99.0                 441.7
# 154               37800.0                      100.0                 461.7
# 166               21500.0                       82.5                 232.0
# 177               34600.0                       96.0                 704.3
# 184               23700.0                       92.5                 411.4
# 190               22000.0                       97.9                 453.5
# 195               26800.0                       99.0                 715.0
# 196               32700.0                       99.0                 680.9
# 198               23400.0                       96.1                 591.0
# 212               23200.0                       77.9                 475.3
# 213               27700.0                       99.0                 543.5
# 214               37800.0                       97.0                 898.0
#
#      Taxa de Natalidade  Taxa de Óbito
# 10                11.03           6.68
# 11                12.14           7.51
# 12                 8.74           9.76
# 19                10.38          10.27
# 22                11.40           7.74
# 36                10.78           7.80
# 38                12.74           4.89
# 54                11.13          10.36
# 66                14.05           8.70
# 68                10.45           9.86
# 69                11.99           9.14
# 76                 8.25          10.62
# 79                 9.68          10.24
# 80                15.93           7.84
# 83                18.79           4.48
# 85                 8.81          10.01
# 91                 7.29           6.29
# 93                13.64           6.72
# 98                14.45           7.82
# 99                11.05          11.19
# 101                8.72          10.40
# 103                9.37           9.16
# 104                9.30           9.28
# 119               10.21           7.18
# 121               11.94           8.41
# 138                9.19          12.91
# 146               10.90           8.68
# 149               13.76           7.53
# 154               11.46           9.40
# 166               15.56           4.72
# 177               10.02           8.17
# 184                9.34           4.28
# 190               10.06           9.72
# 195               10.27          10.31
# 196                9.71           8.49
# 198               12.56           6.48
# 212               18.96           4.40
# 213               10.71          10.13
# 214               14.14           8.26

# %%
dataset['País'] = pd.Series(dataset['País'], dtype = 'str')
dataset['Região'] = pd.Series(dataset['Região'], dtype = 'float')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 13 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   País                                                 227 non-null    object
#  1   Região                                               227 non-null    object
#  2   População                                            227 non-null    int64
#  3   Área (Km)                                            227 non-null    int64
#  4   Densidade Populacional                               227 non-null    float64
#  5   Área Costeira (costa/Área)                           227 non-null    float64
#  6   Taxa de Migração                                     224 non-null    float64
#  7   Taxa de Mortalidade Infantil (por 1000 nascimentos)  224 non-null    float64
#  8   Renda Per capita ($)                                 226 non-null    float64
#  9   Taxa de Alfabetização (%)                            209 non-null    float64
#  10  Telefones (por 1000)                                 223 non-null    float64
#  11  Taxa de Natalidade                                   224 non-null    float64
#  12  Taxa de Óbito                                        223 non-null    float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 23.2+ KB

# %%
# !pip install basemap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting basemap
#   Downloading basemap-1.3.7-cp310-cp310-manylinux1_x86_64.whl (860 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 860.6/860.6 kB 9.7 MB/s eta 0:00:00
# Collecting basemap-data<1.4,>=1.3.2 (from basemap)
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 36.7 MB/s eta 0:00:00
# Collecting pyshp<2.4,>=1.2 (from basemap)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<3.8,>=1.5 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.7.1)
# Collecting pyproj<3.6.0,>=1.9.3 (from basemap)
#   Downloading pyproj-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 81.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25,>=1.22 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj<3.6.0,>=1.9.3->basemap) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.8,>=1.5->basemap) (1.16.0)
# Installing collected packages: pyshp, pyproj, basemap-data, basemap
# Successfully installed basemap-1.3.7 basemap-data-1.3.2 pyproj-3.5.0 pyshp-2.3.1

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# Australia
lat = -26.867996
lon = 134.640937

plt.figure(figsize=(15,8))

m = Basemap(width=12000000,height=9000000,projection='cyl',
            resolution='c',lat_1=45.,lat_2=55,lat_0=lat,lon_0=lon)
# m.drawgreatcircle(dataset['Região'], dataset['Renda Per capita ($)'], lon2=lon, lat2=lat, marker='o', color='k')


m.shadedrelief()
plt.show()
# Out:
# warning: width and height keywords ignored for Cylindrical Equidistant projection

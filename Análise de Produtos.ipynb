# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Produtos.csv", sep = ";")
df
# Out:
#         cnpj fornecedor                                  descrição produto  \
# 0    60.040.599/0003-80  PARAFUSO DE BLOQUEIO 3.5X35MM - REF. 1693535 -...
# 1    04.713.666/0001-48  CONJUNTO PARA ACESSO ABDOMINAL KII FIOS 12MM -...
# 2    04.713.666/0001-48  RECARGA PARA GRAMPEADOR ENDOSCOPICO LINEAR COR...
# 3    60.040.599/0003-80  PARAFUSO BLOQUEIO PBA 3.5X14MM - REF. 1693514 ...
# 4    03.737.792/0001-70  PARAFUSO CORTICAL 3.5X12 AUTO ROSQUEANTE - REF...
# ..                  ...                                                ...
# 301  01.437.707/0001-22  CARGA PARA GRAMPEADOR 45MM BRANCO - REF. FACV4...
# 302  03.737.792/0001-70  PARAFUSO CORTICAL 3.5X14 AUTO ROSQUEANTE - REF...
# 303  13.833.641/0001-79  CARGA PARA ENDO GRAMPEADOR LINEAR CORTANTE BEG...
# 304  11.314.917/0001-87  INTRODUTOR FEMURAL EPTCA 7FR - REF. 834904 - S...
# 305                 NaN          BROCA CARBIDE - REF. PM702 - MEDICAL BURS
#
# ...

# %%
df.groupby(['descrição produto']).sum()

# %%
# %%time
# sns.stripplot(
    
#     data=df, 
#     x="vl unit faturado", 
#     hue="marca"
# );

# %%
figura, eixos = plt.subplots(figsize=(40,40),nrows=1,ncols=1)

sns.scatterplot(data=df, x='descrição produto', 
                y='vl unit faturado', 
                hue='marca', 
                size="qtd. faturada", sizes=(20,150));
# Out:
# C:\Users\mcantarutti\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mcantarutti\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mcantarutti\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mcantarutti\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mcantarutti\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Potenciação
#
# $$a^n = a * a * a * a * a ... a.n$$
#
# O valor de a deve ser: $$a \not= 0$$
#
# <br />
#
# $$a^0=1$$ <br />
# $$a^1=a$$

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# $$a \not= 1 ;  a > 0$$
#
# $$f(x) = a^x$$

# %%
t = np.arange(0., 5., 0.2)

plt.title('Exemplo de funções exponenciais\n', fontsize=30, color='white')
plt.plot(t,t, '--r', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
def funcao_exponencial(base, x):
    v = base ** x
    return v

## Essa função retorna o valor base elevada ao expoente

funcao_exponencial(2, 3)

# %% [markdown]
# ### Mapas utilizando a biblioteca Folium
#
# link : http://dados.recife.pe.gov.br/fa_IR/dataset/localizacao-dos-semaforos

# %%
import folium

# %%
mapa = folium.Map(location=[-23.554144, -46.613848],
                  tiles='Stamen Terrain',
                  zoom_start=10    
                 )
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2abcd684046ef835c2e482176f1b4c12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2abcd684046ef835c2e482176f1b4c12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2abcd684046ef835c2e482176f1b4c12 = L.map(
#                 &quot;map_2abcd684046ef835c2e482176f1b4c12&quot;,
#                 {
#                     center: [-23.554144, -46.613848],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79de785da145c7d879c0c7b6568fa38b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2abcd684046ef835c2e482176f1b4c12);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa = folium.Map(location=[-8.05428,-34.8813],
                  tiles='Stamen Terrain',
                  zoom_start=10    
                 )
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da3ee1cdbacdb1f34918557de3284550 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da3ee1cdbacdb1f34918557de3284550&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da3ee1cdbacdb1f34918557de3284550 = L.map(
#                 &quot;map_da3ee1cdbacdb1f34918557de3284550&quot;,
#                 {
#                     center: [-8.05428, -34.8813],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71637b1359aba1dbbfcd5ef3db652d95 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_da3ee1cdbacdb1f34918557de3284550);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# mapa

mapa = folium.Map(location=[-23.554144, -46.613848],
                  tiles='Stamen Terrain',
                  zoom_start=10    
                 )
# Marcador

tooltip = "Click me!"

folium.Marker(
    [-23.543128, -46.642576], popup="<i>Praça da República</i>", 
    tooltip=tooltip, 
    icon=folium.Icon(color="green")
).add_to(mapa)

# Marcador do tipo círculo 

folium.CircleMarker(
    location=[-23.530542, -46.669612],
    radius=50,
    popup="Laurelhurst Park",
    color="#3186cc",
    fill=True,
    fill_color="#3186cc",
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0340b0d2ad5e316a39751a3a9005dcf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0340b0d2ad5e316a39751a3a9005dcf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0340b0d2ad5e316a39751a3a9005dcf0 = L.map(
#                 &quot;map_0340b0d2ad5e316a39751a3a9005dcf0&quot;,
#                 {
#                     center: [-23.554144, -46.613848],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e31a452ba0606a99595dd054082ea26 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0340b0d2ad5e316a39751a3a9005dcf0);
#
#
#             var marker_a63286ead180289e3fad48f13c4f1502 = L.marker(
#                 [-23.543128, -46.642576],
#                 {}
#             ).addTo(map_0340b0d2ad5e316a39751a3a9005dcf0);
#
#
#             var icon_f80ddc9bc43105e88e4d60ab3fcdac02 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a63286ead180289e3fad48f13c4f1502.setIcon(icon_f80ddc9bc43105e88e4d60ab3fcdac02);
#
#
#         var popup_75f7c343c22c15cc757658e87c0eb4ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8718d2ccf12ad18e9778dcf55a093c4f = $(`&lt;div id=&quot;html_8718d2ccf12ad18e9778dcf55a093c4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Praça da República&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_75f7c343c22c15cc757658e87c0eb4ec.setContent(html_8718d2ccf12ad18e9778dcf55a093c4f);
#
#
#
#         marker_a63286ead180289e3fad48f13c4f1502.bindPopup(popup_75f7c343c22c15cc757658e87c0eb4ec)
#         ;
#
#
#
#
#             marker_a63286ead180289e3fad48f13c4f1502.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_a765d09edb291d70a8bf240a71de9f82 = L.circleMarker(
#                 [-23.530542, -46.669612],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0340b0d2ad5e316a39751a3a9005dcf0);
#
#
#         var popup_1ba362660fa3d373bbf8d5aeb7aa6d53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3126a6fa5a62e436b9dd5acf641d7b2e = $(`&lt;div id=&quot;html_3126a6fa5a62e436b9dd5acf641d7b2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laurelhurst Park&lt;/div&gt;`)[0];
#                 popup_1ba362660fa3d373bbf8d5aeb7aa6d53.setContent(html_3126a6fa5a62e436b9dd5acf641d7b2e);
#
#
#
#         circle_marker_a765d09edb291d70a8bf240a71de9f82.bindPopup(popup_1ba362660fa3d373bbf8d5aeb7aa6d53)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# exibindo as coordenadas ao clicar

mapa.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0340b0d2ad5e316a39751a3a9005dcf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0340b0d2ad5e316a39751a3a9005dcf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0340b0d2ad5e316a39751a3a9005dcf0 = L.map(
#                 &quot;map_0340b0d2ad5e316a39751a3a9005dcf0&quot;,
#                 {
#                     center: [-23.554144, -46.613848],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e31a452ba0606a99595dd054082ea26 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0340b0d2ad5e316a39751a3a9005dcf0);
#
#
#             var marker_a63286ead180289e3fad48f13c4f1502 = L.marker(
#                 [-23.543128, -46.642576],
#                 {}
#             ).addTo(map_0340b0d2ad5e316a39751a3a9005dcf0);
#
#
#             var icon_f80ddc9bc43105e88e4d60ab3fcdac02 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a63286ead180289e3fad48f13c4f1502.setIcon(icon_f80ddc9bc43105e88e4d60ab3fcdac02);
#
#
#         var popup_75f7c343c22c15cc757658e87c0eb4ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8718d2ccf12ad18e9778dcf55a093c4f = $(`&lt;div id=&quot;html_8718d2ccf12ad18e9778dcf55a093c4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Praça da República&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_75f7c343c22c15cc757658e87c0eb4ec.setContent(html_8718d2ccf12ad18e9778dcf55a093c4f);
#
#
#
#         marker_a63286ead180289e3fad48f13c4f1502.bindPopup(popup_75f7c343c22c15cc757658e87c0eb4ec)
#         ;
#
#
#
#
#             marker_a63286ead180289e3fad48f13c4f1502.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_a765d09edb291d70a8bf240a71de9f82 = L.circleMarker(
#                 [-23.530542, -46.669612],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0340b0d2ad5e316a39751a3a9005dcf0);
#
#
#         var popup_1ba362660fa3d373bbf8d5aeb7aa6d53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3126a6fa5a62e436b9dd5acf641d7b2e = $(`&lt;div id=&quot;html_3126a6fa5a62e436b9dd5acf641d7b2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laurelhurst Park&lt;/div&gt;`)[0];
#                 popup_1ba362660fa3d373bbf8d5aeb7aa6d53.setContent(html_3126a6fa5a62e436b9dd5acf641d7b2e);
#
#
#
#         circle_marker_a765d09edb291d70a8bf240a71de9f82.bindPopup(popup_1ba362660fa3d373bbf8d5aeb7aa6d53)
#         ;
#
#
#
#
#                 var lat_lng_popup_6f161a282482957255aa628eae6ca334 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_6f161a282482957255aa628eae6ca334
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_0340b0d2ad5e316a39751a3a9005dcf0);
#                     }
#                 map_0340b0d2ad5e316a39751a3a9005dcf0.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import numpy as np
from folium import plugins

# %%
df_def = pd.read_csv('semaforodefvisual.csv', sep=';', encoding='UTF-8')

df_cicli = pd.read_csv('semaforociclista.csv', sep=';')

df_ped = pd.read_csv('semaforoiluminacao.csv', sep=';')

# %%
df_ped
# Out:
#     semafororo                        localizacao1  \
# 0           20               Av. Marquez de Olinda
# 1           37         Av. Gov. Agamenon Magalhães
# 2           50                     Rua José Osório
# 3           69         Av. Gov. Agamenon Magalhães
# 4           75         Av. Gov. Agamenon Magalhães
# 5           82                 Av. Dr. José Rufino
# 6          104                      Av. Boa Viagem
# 7          131                        Av. Beberibe
# 8          137              Av. Herculano Bandeira
# 9          170                     Rua do Príncipe
# 10         173         Av. Gov. Agamenon Magalhães
# 11         237                   Rua Real da Torre
# 12         271              Av. Abdias de Carvalho
# 13         272              Av. Abdias de Carvalho
# 14         277                 Av. Antônio de Góis
# 15         297               Av. Domingos Ferreira
# 16         309        Av. Conselheiro Rosa e Silva
# 17         325                       Av. Dois Rios
# 18         327              Av. Abdias de Carvalho
# 19         328              Av. Abdias de Carvalho
# 20         336                          Av. Recife
# 21         338               Av. Domingos Ferreira
# 22         370                    Av. 17 de Agosto
# 23         407             Rua Barão de Souza Leão
# 24         409                  Rua Conde de Irajá
# 25         424  Av. Norte Miguel Arraes de Alencar
# 26         432                 Rua Guilherme Pinto
# 27         475                       Av. Dois Rios
# 28         486              Av. Conde da Boa Vista
# 29         501           Av. Mascarenhas de Morais
# 30         502           Av. Mascarenhas de Morais
# 31         530           Av. Mascarenhas de Morais
# 32         531           Av. Mascarenhas de Morais
# 33         544                  Rua Félix de Brito
# 34         594                       Av. Dois Rios
# 35         617                          Av. Recife
# 36         624               Av. Visc. de Suassuna
#
#                              localizacao2           bairro  latitude  \
# 0                       Rua Madre de Deus           Recife -8.063611
# 1                         Av. Rui Barbosa           Graças -8.052422
# 2             Rua Visconde de Albuquerque         Madalena -8.053297
# 3                           Rua Paissandú        Paissandu -8.062396
# 4           Av. Carlos de Lima Cavalcante            Derby -8.056709
# 5                       Rua João Teixeira         Estância -8.084694
# 6                  Av. Herculano Bandeira             Pina -8.091769
# 7                Av. Prof. José dos Anjos  Ponto de Parada -8.027954
# 8                      Rua Miranda Falcão             Pina -8.088874
# 9                      Em frente à UNICAP         Soledade -8.055811
# 10                 Rua Dr. Bandeira Filho           Graças -8.051467
# 11    Em frente ao Colégio Joaquim Távora         Madalena -8.055776
# 12      Próximo a UPA - Torrões (Cid/Sub)          Torrões -8.063964
# 13      Próximo a UPA - Torrões (Sub/Cid)          Torrões -8.064074
# 14                     Rua Miranda Falcão             Pina -8.087743
# 15  Gilson M. Guimarães (antigo SUPERBOX)       Boa Viagem -8.105434
# 16         Em frente ao Hospital do IPSEP       Espinheiro -8.047866
# 17                  Próx. a Rua Rio Pajeú            Ibura -8.113534
# 18         Em frente a Estácio - Sub/Cid.            Prado -8.062513
# 19             Em frente à FIR - Cid/Sub.            Prado -8.062363
# 20  Em frente ao Hospital Geral de Areias           Caçote -8.100611
# 21                       Rua Bruno Veloso       Boa Viagem -8.121631
# 22                      Praça do Monteiro         Monteiro -8.027749
# 23     Em frente ao Colégio Santos Dumont       Boa Viagem -8.132167
# 24                         Praça da Torre            Torre -8.047001
# 25                             Rua Bujarú        Macaxeira -8.018246
# 26       Em frente ao Instituto dos Cegos           Graças -8.052197
# 27                           Rua Rio Chuí            Ibura -8.115407
# 28                   Rua Sete de Setembro        Boa Vista -8.061073
# 29    Proxímo a Estrada dos Frigoríficos,      Imbiribeira -8.103560
# 30                             Rua Itália      Imbiribeira -8.103214
# 31                  Em Frente a UNIBRATEC      Imbiribeira -8.127410
# 32                             Av. Recife            Ibura -8.127376
# 33                Av. Prof. João Medeiros       Boa Viagem -8.115377
# 34                    Em frente ao Nº 110            Ibura -8.109820
# 35  Em frente ao Hospital Geral de Areias           Areias -8.100470
# 36                    Em frente ao nº 500      Santo Amaro -8.052592
#
#      longitude   tipo      funcionamento
# 0   -34,873672  E/Git           Veicular
# 1   -34,895758  E/Git           Veicular
# 2   -34,906797  E/Git        Veic.C/Ped.
# 3   -34,897553  E/Git  Veic.C/Ped.Paral.
# 4   -34,897924  E/Git           Veicular
# 5   -34,928126  E/Git   Veic.C/Ped.Ocas.
# 6   -34,882053  E/Git  Veic.C/Ped.Paral.
# 7   -34,892919  E/Git           Veicular
# 8   -34,885203  E/Git     Ocasional/Ped.
# 9   -34,887862      E     Ocasional/Ped.
# 10  -34,895077  E/Git           Veicular
# 11  -34,909047  E/Git     Ocasional/Ped.
# 12  -34,935793  E/Git     Ocasional/Ped.
# 13  -34,935713  E/Git     Ocasional/Ped.
# 14  -34,884504  E/Git           Pedestre
# 15  -34,889648  E/Git  Veic.C/Ped.Paral.
# 16  -34,896847  E/Git     Ocasional/Ped.
# 17  -34,938989  E/Git     Ocasional/Ped.
# 18  -34,917033      E     Ocasional/Ped.
# 19  -34,917038      E     Ocasional/Ped.
# 20  -34,928171  E/Git     Ocasional/Ped.
# 21   -34,89905  E/Git           Veicular
# 22  -34,928219  E/Git     Ocasional/Ped.
# 23  -34,907281  E/Git     Ocasional/Ped.
# 24  -34,913636      E     Ocasional/Ped.
# 25  -34,928354      E     Ocasional/Ped.
# 26  -34,902136  E/Git     Ocasional/Ped.
# 27  -34,940297  E/Git     Ocasional/Ped.
# 28  -34,883421  E/Git     Ocasional/Ped.
# 29  -34,910724  E/Git     Ocasional/Ped.
# 30  -34,910852  E/Git     Ocasional/Ped.
# 31    -34,9153  E/Git     Ocasional/Ped.
# 32  -34,915543  E/Git     Ocasional/Ped.
# 33  -34,900496  E/Git           Veicular
# 34  -34,936173  E/Git     Ocasional/Ped.
# 35  -34,928072  E/Git     Ocasional/Ped.
# 36  -34,886268      E     Ocasional/Ped.

# %%
coordenadas_cicli = []

for lat, lon in zip(df_cicli['latitude'].values, df_cicli['longitude'].values):
    coordenadas_cicli.append([lat, lon])

coordenadas_cicli
# Out:
# [[-8.106806, -34.887726],
#  [-8.060502, -34.888369],
#  [-8.061707, -34.907595],
#  [-8.059303, -34.89131],
#  [-8.151128, -34.907787],
#  [-8.091769, -34.882053],
#  [-8.09974, -34.884436],
#  [-8.0959, -34.883112],
#  [-8.120273, -34.895078],
#  [-8.125274, -34.897142],
#  [-8.108815, -34.888605],
#  [-8.101374, -34.885168],
#  [-8.094196, -34.882681],
#  [-8.121939, -34.895997],
#  [-8.098279, -34.883756],
#  [-8.111829, -34.889969],
#  [-8.104509, -34.886665],
#  [-8.137039, -34.901918],
#  [-8.145063, -34.905147],
#  [-8.148817, -34.906892],
#  [-8.129072, -34.898562],
#  [-8.05396, -34.881592],
#  [-8.045157, -34.898335],
#  [-8.146655, -34.905891],
#  [-8.064105, -34.87637],
#  [-8.059565, -34.890071],
#  [-8.08955, -34.882736],
#  [-8.053507, -34.928933],
#  [-8.039897, -34.904022],
#  [-8.043981, -34.902188],
#  [-8.065287, -34.927227],
#  [-8.076993, -34.909194],
#  [-8.061118, -34.904854],
#  [-8.046217, -34.894335],
#  [-8.063488, -34.894867],
#  [-8.062545, -34.932194],
#  [-8.075838, -34.909021],
#  [-8.135429, -34.901386],
#  [-8.139063, -34.902598],
#  [-8.133277, -34.900494],
#  [-8.087182, -34.884907],
#  [-8.118568, -34.894059],
#  [-8.115285, -34.89221],
#  [-8.116989, -34.893167],
#  [-8.046996, -34.940548],
#  [-8.110297, -34.88929],
#  [-8.109476, -34.909099]]

# %%
coordenadas_ped = []

for lat, lon in zip(df['latitude'].values, df['longitude'].values):
    coordenadas_ped.append([lat, lon])
    
coordenadas_ped
# Out:
# [[-8.063874, -34.880922],
#  [-8.0662, -34.877317],
#  [-8.060773, -34.88405],
#  [-8.059567, -34.886443],
#  [-8.057554, -34.889962],
#  [-8.055068, -34.882265],
#  [-8.058197, -34.907149],
#  [-8.072364, -34.880475],
#  [-8.043536, -34.887514],
#  [-8.060402, -34.894791],
#  [-8.121887, -34.89677],
#  [-8.106314, -34.911444],
#  [-8.062052, -34.881642],
#  [-8.055811, -34.887862],
#  [-8.015859, -34.943677],
#  [-8.060701, -34.870413],
#  [-8.071082, -34.880603],
#  [-8.063454, -34.882531],
#  [-8.092925, -34.941609],
#  [-8.036687, -34.935337],
#  [-8.020731, -34.935794],
#  [-8.029358, -34.925824],
#  [-8.065063, -34.87411],
#  [-8.050299, -34.921551],
#  [-8.04813, -34.925055],
#  [-8.048288, -34.925162],
#  [-8.038388, -34.942657],
#  [-8.038523, -34.942786],
#  [-8.04626, -34.928452],
#  [-8.092065, -34.96148],
#  [-8.096481, -34.909728],
#  [-8.116596, -34.94113],
#  [-8.065287, -34.927227],
#  [-8.062513, -34.917033],
#  [-8.062363, -34.917038],
#  [-8.054344, -34.871957],
#  [-8.032146, -34.902614],
#  [-8.032199, -34.902509],
#  [-8.065242, -34.908034],
#  [-8.04493, -34.880372],
#  [-8.026759, -34.917731],
#  [-8.132167, -34.907281],
#  [-8.047001, -34.913636],
#  [-8.052197, -34.902136],
#  [-8.106415, -34.911255],
#  [-8.130714, -34.902615],
#  [-8.043816, -34.887198],
#  [-8.115407, -34.940297],
#  [-8.03191, -34.892],
#  [-8.061073, -34.883421],
#  [-8.060398, -34.877658],
#  [-8.064945, -34.909022],
#  [-8.065091, -34.90918],
#  [-8.056757, -34.899417],
#  [-8.093115, -34.943245],
#  [-8.056667, -34.899444],
#  [-8.058852, -34.889911],
#  [-8.063632, -34.930486],
#  [-8.045478, -34.92176],
#  [-8.044731, -34.907491],
#  [-8.063384, -34.879344],
#  [-8.046407, -34.92861],
#  [-8.043293, -34.93376],
#  [-8.036567, -34.946324],
#  [-8.034399, -34.949951],
#  [-8.043459, -34.933822],
#  [-8.048978, -34.878004]]

# %%
coordenadas_def = []

for lat, lon in zip(df_def['latitude'].values, df_def['longitude'].values):
    coordenadas_def.append([lat, lon])

coordenadas_def
# Out:
# [[-8.063874, -34.880922],
#  [-8.0662, -34.877317],
#  [-8.060773, -34.88405],
#  [-8.059567, -34.886443],
#  [-8.057554, -34.889962],
#  [-8.055068, -34.882265],
#  [-8.058197, -34.907149],
#  [-8.072364, -34.880475],
#  [-8.043536, -34.887514],
#  [-8.060402, -34.894791],
#  [-8.121887, -34.89677],
#  [-8.106314, -34.911444],
#  [-8.062052, -34.881642],
#  [-8.055811, -34.887862],
#  [-8.015859, -34.943677],
#  [-8.060701, -34.870413],
#  [-8.071082, -34.880603],
#  [-8.063454, -34.882531],
#  [-8.092925, -34.941609],
#  [-8.036687, -34.935337],
#  [-8.020731, -34.935794],
#  [-8.029358, -34.925824],
#  [-8.065063, -34.87411],
#  [-8.050299, -34.921551],
#  [-8.04813, -34.925055],
#  [-8.048288, -34.925162],
#  [-8.038388, -34.942657],
#  [-8.038523, -34.942786],
#  [-8.04626, -34.928452],
#  [-8.092065, -34.96148],
#  [-8.096481, -34.909728],
#  [-8.116596, -34.94113],
#  [-8.065287, -34.927227],
#  [-8.062513, -34.917033],
#  [-8.062363, -34.917038],
#  [-8.054344, -34.871957],
#  [-8.032146, -34.902614],
#  [-8.032199, -34.902509],
#  [-8.065242, -34.908034],
#  [-8.04493, -34.880372],
#  [-8.026759, -34.917731],
#  [-8.132167, -34.907281],
#  [-8.047001, -34.913636],
#  [-8.052197, -34.902136],
#  [-8.106415, -34.911255],
#  [-8.130714, -34.902615],
#  [-8.043816, -34.887198],
#  [-8.115407, -34.940297],
#  [-8.03191, -34.892],
#  [-8.061073, -34.883421],
#  [-8.060398, -34.877658],
#  [-8.064945, -34.909022],
#  [-8.065091, -34.90918],
#  [-8.056757, -34.899417],
#  [-8.093115, -34.943245],
#  [-8.056667, -34.899444],
#  [-8.058852, -34.889911],
#  [-8.063632, -34.930486],
#  [-8.045478, -34.92176],
#  [-8.044731, -34.907491],
#  [-8.063384, -34.879344],
#  [-8.046407, -34.92861],
#  [-8.043293, -34.93376],
#  [-8.036567, -34.946324],
#  [-8.034399, -34.949951],
#  [-8.043459, -34.933822],
#  [-8.048978, -34.878004]]

# %%
import folium
mapa = folium.Map(location=[-8.05428,-34.8813], zoom_start=10, tile='Stamen Terrain')

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01716d94abf69e352c7f452018d50f0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01716d94abf69e352c7f452018d50f0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01716d94abf69e352c7f452018d50f0b = L.map(
#                 &quot;map_01716d94abf69e352c7f452018d50f0b&quot;,
#                 {
#                     center: [-8.05428, -34.8813],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     tile: &quot;Stamen Terrain&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19d1a5848cc774f0ecf4e8a92e06235c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01716d94abf69e352c7f452018d50f0b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa.add_child(plugins.HeatMap(coordenadas))
mapa.add_child(plugins.HeatMap(coordenadas_cicli))
mapa.add_child(plugins.HeatMap(coordenadas_ped))


mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01716d94abf69e352c7f452018d50f0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01716d94abf69e352c7f452018d50f0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01716d94abf69e352c7f452018d50f0b = L.map(
#                 &quot;map_01716d94abf69e352c7f452018d50f0b&quot;,
#                 {
#                     center: [-8.05428, -34.8813],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     tile: &quot;Stamen Terrain&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19d1a5848cc774f0ecf4e8a92e06235c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01716d94abf69e352c7f452018d50f0b);
#
#
#             var heat_map_e2c094490dfab6ab967c8dd0cdd3e612 = L.heatLayer(
#                 [[-8.063874, -34.880922], [-8.0662, -34.877317], [-8.060773, -34.88405], [-8.059567, -34.886443], [-8.057554, -34.889962], [-8.055068, -34.882265], [-8.058197, -34.907149], [-8.072364, -34.880475], [-8.043536, -34.887514], [-8.060402, -34.894791], [-8.121887, -34.89677], [-8.106314, -34.911444], [-8.062052, -34.881642], [-8.055811, -34.887862], [-8.015859, -34.943677], [-8.060701, -34.870413], [-8.071082, -34.880603], [-8.063454, -34.882531], [-8.092925, -34.941609], [-8.036687, -34.935337], [-8.020731, -34.935794], [-8.029358, -34.925824], [-8.065063, -34.87411], [-8.050299, -34.921551], [-8.04813, -34.925055], [-8.048288, -34.925162], [-8.038388, -34.942657], [-8.038523, -34.942786], [-8.04626, -34.928452], [-8.092065, -34.96148], [-8.096481, -34.909728], [-8.116596, -34.94113], [-8.065287, -34.927227], [-8.062513, -34.917033], [-8.062363, -34.917038], [-8.054344, -34.871957], [-8.032146, -34.902614], [-8.032199, -34.902509], [-8.065242, -34.908034], [-8.04493, -34.880372], [-8.026759, -34.917731], [-8.132167, -34.907281], [-8.047001, -34.913636], [-8.052197, -34.902136], [-8.106415, -34.911255], [-8.130714, -34.902615], [-8.043816, -34.887198], [-8.115407, -34.940297], [-8.03191, -34.892], [-8.061073, -34.883421], [-8.060398, -34.877658], [-8.064945, -34.909022], [-8.065091, -34.90918], [-8.056757, -34.899417], [-8.093115, -34.943245], [-8.056667, -34.899444], [-8.058852, -34.889911], [-8.063632, -34.930486], [-8.045478, -34.92176], [-8.044731, -34.907491], [-8.063384, -34.879344], [-8.046407, -34.92861], [-8.043293, -34.93376], [-8.036567, -34.946324], [-8.034399, -34.949951], [-8.043459, -34.933822], [-8.048978, -34.878004]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_01716d94abf69e352c7f452018d50f0b);
#
#
#             var heat_map_22b895d26d4207c8560e8e0332de5d79 = L.heatLayer(
#                 [[-8.106806, -34.887726], [-8.060502, -34.888369], [-8.061707, -34.907595], [-8.059303, -34.89131], [-8.151128, -34.907787], [-8.091769, -34.882053], [-8.09974, -34.884436], [-8.0959, -34.883112], [-8.120273, -34.895078], [-8.125274, -34.897142], [-8.108815, -34.888605], [-8.101374, -34.885168], [-8.094196, -34.882681], [-8.121939, -34.895997], [-8.098279, -34.883756], [-8.111829, -34.889969], [-8.104509, -34.886665], [-8.137039, -34.901918], [-8.145063, -34.905147], [-8.148817, -34.906892], [-8.129072, -34.898562], [-8.05396, -34.881592], [-8.045157, -34.898335], [-8.146655, -34.905891], [-8.064105, -34.87637], [-8.059565, -34.890071], [-8.08955, -34.882736], [-8.053507, -34.928933], [-8.039897, -34.904022], [-8.043981, -34.902188], [-8.065287, -34.927227], [-8.076993, -34.909194], [-8.061118, -34.904854], [-8.046217, -34.894335], [-8.063488, -34.894867], [-8.062545, -34.932194], [-8.075838, -34.909021], [-8.135429, -34.901386], [-8.139063, -34.902598], [-8.133277, -34.900494], [-8.087182, -34.884907], [-8.118568, -34.894059], [-8.115285, -34.89221], [-8.116989, -34.893167], [-8.046996, -34.940548], [-8.110297, -34.88929], [-8.109476, -34.909099]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_01716d94abf69e352c7f452018d50f0b);
#
#
#             var heat_map_507aa67bcc879e48d0687ff12ec9f2c2 = L.heatLayer(
#                 [[-8.063874, -34.880922], [-8.0662, -34.877317], [-8.060773, -34.88405], [-8.059567, -34.886443], [-8.057554, -34.889962], [-8.055068, -34.882265], [-8.058197, -34.907149], [-8.072364, -34.880475], [-8.043536, -34.887514], [-8.060402, -34.894791], [-8.121887, -34.89677], [-8.106314, -34.911444], [-8.062052, -34.881642], [-8.055811, -34.887862], [-8.015859, -34.943677], [-8.060701, -34.870413], [-8.071082, -
